# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Gemini
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Embedded/Gemini'
# /content

# %%
# %cd /content/drive/MyDrive/Gemini
# !wget -O GEMINI_AE.zip https://zenodo.org/records/10207613/files/GEMINI_AE.zip?download=1
# !unzip GEMINI_AE.zip
# Out:
# /content/drive/MyDrive/Study
# --2024-08-07 02:41:21--  https://zenodo.org/records/10207613/files/GEMINI_AE.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.103.159, 188.184.98.238, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 758494 (741K) [application/octet-stream]
# Saving to: ‘GEMINI_AE.zip’
#
# GEMINI_AE.zip       100%[===================>] 740.72K   676KB/s    in 1.1s
#
# 2024-08-07 02:41:23 (676 KB/s) - ‘GEMINI_AE.zip’ saved [758494/758494]
#
# Archive:  GEMINI_AE.zip
#    creating: GEMINI/
#   inflating: GEMINI/.gitignore
#   inflating: GEMINI/compare.sh
#   inflating: GEMINI/dse.sh
#    creating: GEMINI/expected_results/
#   inflating: GEMINI/expected_results/comparison_result.log
#   inflating: GEMINI/expected_results/DSE_result.csv
#   inflating: GEMINI/expected_results/Fig_5.csv
#   inflating: GEMINI/Fig5_reproduce.py
#    creating: GEMINI/include/
# ...

# %%
# %cd GEMINI
# !make
# Out:
# /content/drive/MyDrive/Study/GEMINI
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/alexnet.cpp -MMD -o build/objects/src/nns/alexnet.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/darknet19.cpp -MMD -o build/objects/src/nns/darknet19.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/densenet.cpp -MMD -o build/objects/src/nns/densenet.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/gnmt.cpp -MMD -o build/objects/src/nns/gnmt.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/googlenet.cpp -MMD -o build/objects/src/nns/googlenet.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/incep_resnet.cpp -MMD -o build/objects/src/nns/incep_resnet.o
# g++ -Wall -Wextra --std=c++17 -O3 -Iinclude/ -c src/nns/nns.cpp -MMD -o build/objects/src/nns/nns.o
# src/nns/nns.cpp: In function ‘Network gen_network(std::string)’:
# ...

# %%
# !pip install -r requirements.txt
# !apt-get install bc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 2.1 MB/s eta 0:00:00
# ...

# %%
# !chmod +x summary.sh
# !chmod +x dse.sh

# %%
# !./dse.sh
# Out:
# ******************** 72TOPS DSE Start ********************
# [INFO] Check output in dir /content/drive/MyDrive/Study/GEMINI/dse_log/2024_08_07_02_58_15.
# [INFO] DSE running...
# [INFO] Summarizing experiment results...
# [INFO] Summary at /content/drive/MyDrive/Study/GEMINI/dse_log/2024_08_07_02_58_15/result.xlsx
# [INFO] Summary accomplished.
# [INFO] Best Arch found.
# Arch parameters have been writed into /content/drive/MyDrive/Study/GEMINI/dse_log/2024_08_07_02_58_15/best_arch.txt
# Best Arch is: core number of X line= 6.
# core number of Y line = 6.
# XCut= 1, YCut= 2.
# NoP bandwidth = 16 GB/s.
# NoC bandwidth = 32 GB/s.
# DDR bandwidth = 144 GB/s.
# mac per core = 1024, UBUF size = 2048 KB.
# ******************** 72TOPS DSE Finish *******************

# %%
# !./compare.sh dse_log/2024_08_07_02_58_15/best_arch.txt
# Out:
# Making output foler /content/drive/MyDrive/Study/GEMINI/compare_log/2024_08_07_04_17_47.
# **************** Comparison Experiment ****************
# [INFO] Comparison experiment starts.
# [INFO] Experiment time: 0 h 17 m 18 s (1038)seconds.
# [INFO] Analysation starts.
# ------------ Comparison Result ------------
# G-Arch with G-Mapping improves 41.251% energy efficiency over Simba Arch with T-Mapping on average.
# G-Arch with G-Mapping improves 97.980% performance over Simba Arch with T-Mapping on average.
# G-Arch costs  0.143% more money over Simba Arch.
# [INFO] Analysation accomplishes.
# [INFO] Experiment log has been writed into /content/drive/MyDrive/Study/GEMINI/compare_log/2024_08_07_04_17_47/compare.log.
# [INFO] Optimization rate has been writed into /content/drive/MyDrive/Study/GEMINI/compare_log/2024_08_07_04_17_47/comparison_result.log.
# [INFO] File format converting...
# **************** Experiment Terminates ****************

# %%
# !python3 Fig5_reproduce.py compare_log/2024_08_07_04_17_47/compare.csv
# Out:
# Process succeed.
